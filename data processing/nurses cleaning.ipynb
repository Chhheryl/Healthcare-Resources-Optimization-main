# %%
import pandas as pd
import numpy as np
import os

# %%
datadir = '../data'

file_path = os.path.join(datadir, 'nurses_deaggregated_by_population.xlsx')

# Read the Excel file into a pandas DataFrame
nurses_df = pd.read_excel(file_path)

# %%
nurses_df.head()
# Out:
#     area                   area_title  area_type  naics     naics_title  \
# 0  10180                  Abilene, TX        4.0    0.0  Cross-industry
# 1  10380        Aguadilla-Isabela, PR        4.0    0.0  Cross-industry
# 2  10420                    Akron, OH        4.0    0.0  Cross-industry
# 3  10540                   Albany, OR        4.0    0.0  Cross-industry
# 4  10580  Albany-Schenectady-Troy, NY        4.0    0.0  Cross-industry
#
#           i_group  own_code occ_code          occ_title   o_group  ...  \
# 0  cross-industry    1235.0  29-1141  Registered Nurses  detailed  ...
# 1  cross-industry    1235.0  29-1141  Registered Nurses  detailed  ...
# 2  cross-industry    1235.0  29-1141  Registered Nurses  detailed  ...
# 3  cross-industry    1235.0  29-1141  Registered Nurses  detailed  ...
# 4  cross-industry    1235.0  29-1141  Registered Nurses  detailed  ...
#
#   a_pct75 a_pct90 annual hourly                        title      category  \
# ...

# %%
# Replace '**' with NaN in the 'tot_emp' column
nurses_df['tot_emp'] = nurses_df['tot_emp'].replace('**', np.nan)

# Drop rows where 'tot_emp' column contains NaN values
nurses_df = nurses_df.dropna(subset=['tot_emp'])

# %%
nurses_df = nurses_df.reset_index(drop=True)

# %%
nurses_df.columns
# Out:
# Index(['area', 'area_title', 'area_type', 'naics', 'naics_title', 'i_group',
#        'own_code', 'occ_code', 'occ_title', 'o_group', 'tot_emp', 'emp_prse',
#        'jobs_1000', 'loc_quotient', 'pct_total', 'h_mean', 'a_mean',
#        'mean_prse', 'h_pct10', 'h_pct25', 'h_median', 'h_pct75', 'h_pct90',
#        'a_pct10', 'a_pct25', 'a_median', 'a_pct75', 'a_pct90', 'annual',
#        'hourly', 'title', 'category', 'county_code', 'div_code', 'county_name',
#        'population'],
#       dtype='object')

# %%
nurses_df.drop()

# %%
output_file = '../data/cleaned_nurses_data.xlsx'  

# Save the cleaned DataFrame to a new Excel file
nurses_df.to_excel(output_file, index=False)
